# %%
import requests
from bs4 import BeautifulSoup
from konlpy.tag import Kkma
from konlpy.tag import Okt

# %%
# 크롤링
url = 'https://news.naver.com/main/read.nhn?mode=LS2D&mid=shm&sid1=105&sid2=230&oid=417&aid=0000370268'
response = requests.get(url)
# response.encoding = 'utf-8'
soup = BeautifulSoup(response.text,'html.parser')
news = soup.select('div[id="articleBodyContents"]')
for s in soup('script'):
    s.extract()
# Out:
# ['/ 사진 =NHN 엔터테인먼트 바둑 인공지능 (AI) ‘ 한 돌’ 이 프로기사를 상대로 3 연승을 거두며 무서운 기세를 올렸다.', '10일 NHN 엔터테인먼트에 따르면 한 돌은 전날 밤 8시 펼쳐진 김 지석 9 단과의 대국에서 1 시간 43 분만에 246 수로 백 불계승을 거뒀다.', '한 돌은 신민 준/ 이동 훈 9 단에 이어 국내 바둑 랭킹 3위인 김 지석 9 단까지 꺾으며 적수가 없음을 증명했다.', '대국에 앞서 김 지석 9 단은 “ 한 돌의 바둑을 유심히 많이 봤다 ”며 “ 실력은 사람과 비교하기 힘들 정도로 강하지만 승부는 모르는 것이기 때문에 마지막까지 이기기 위해 최선을 다할 것” 이라고 각오를 밝혔다.', '두 번의 대국에서 완승을 거둔 한 돌은 김 지석 9 단과의 경기에서도 탄탄한 행마로 국면을 설계했다.', '한 돌은 우 중앙 붙임수 이후 중앙 일대에 집을 장만하면서 승기를 잡았다.', '이번 대결 들어 처음으로 끝내기를 보여주며 계가까지 간 바둑은 한 돌의 느슨함과 김 지석 9 단의 추격으로 차이가 좁혀 졌으나 덤이 나오지 않았다.', '국 후 김 지석 9 단은 “ 결과는 큰 차이가 아니었지만 마지막에 한 돌이 봐준 것 같은 느낌” 이라며 “ 예상한 수를 두니까 갑갑했고 어디서 크게 실수했는지 잘 모르겠지만 많이 나빴던 것 같다” 고 말했다.', '이어 그는 “ 사람과 대국한다면 나중에 기회가 올 거라는 생각을 가졌을 텐데 AI와 두다 보니 심리적으로 위축된 점도 있었다” 고 덧붙였다.', '한편 한 돌은 오는 11일 밤 8시부터 국내 바둑 랭킹 2위 박정 환 9 단과 제 4 국을 갖는다.', '해설은 강남 바둑센터와 도 은 교 프로가 맡을 예정이며 시청자는 유 튜브로 실시간 감상할 수 있다.', "채 성오 기자 cso86 @mt .co .kr< 저작권자 ⓒ ' 성공을 꿈꾸는 사람들의 경제 뉴스' 머니 S, 무단 전재 및 재배포 금지>▶ 고수들의 재테크 비법 ▶ 박학 다식 ' 이건 희칼 럼'"]

# %%
# 토큰화
for newsText in news:
    token = Kkma().sentences(newsText.text)

# %%
# 형태소분석
oktTag = []
okt = Okt()
for sentence in token:
    oktTag += okt.pos(sentence)

print(oktTag)
# Out:
# [('/', 'Punctuation'), ('사진', 'Noun'), ('=', 'Punctuation'), ('NHN', 'Alpha'), ('엔터테인먼트', 'Noun'), ('바둑', 'Noun'), ('인공', 'Noun'), ('지능', 'Noun'), ('(', 'Punctuation'), ('AI', 'Alpha'), (')', 'Punctuation'), ('‘', 'Foreign'), ('한', 'Verb'), ('돌', 'Noun'), ('’', 'Punctuation'), ('이', 'Noun'), ('프로', 'Noun'), ('기사', 'Noun'), ('를', 'Josa'), ('상대로', 'Noun'), ('3', 'Number'), ('연승', 'Noun'), ('을', 'Josa'), ('거두며', 'Verb'), ('무서운', 'Adjective'), ('기세', 'Noun'), ('를', 'Josa'), ('올렸다', 'Verb'), ('.', 'Punctuation'), ('10일', 'Number'), ('NHN', 'Alpha'), ('엔터테인먼트', 'Noun'), ('에', 'Josa'), ('따르면', 'Verb'), ('한', 'Verb'), ('돌은', 'Verb'), ('전날', 'Noun'), ('밤', 'Noun'), ('8시', 'Number'), ('펼쳐진', 'Verb'), ('김', 'Noun'), ('지석', 'Noun'), ('9', 'Number'), ('단', 'Noun'), ('과의', 'Josa'), ('대국', 'Noun'), ('에서', 'Josa'), ('1', 'Number'), ('시간', 'Noun'), ('43', 'Number'), ('분만', 'Noun'), ('에', 'Josa'), ('246', 'Number'), ('수로', 'Noun'), ('백', 'Noun'), ('불계승', 'Noun'), ('을', 'Josa'), ('거뒀다', 'Verb'), ('.', 'Punctuation'), ('한', 'Verb'), ('돌은', 'Verb'), ('신민', 'Noun'), ('준', 'Noun'), ('/', 'Punctuation'), ('이동', 'Noun'), ('훈', 'Noun'), ('9', 'Number'), ('단', 'Noun'), ('에', 'Josa'), ('이어', 'Verb'), ('국내', 'Noun'), ('바둑', 'Noun'), ('랭킹', 'Noun'), ('3', 'Number'), ('위인', 'Noun'), ('김', 'Noun'), ('지석', 'Noun'), ('9', 'Number'), ('단', 'Noun'), ('까지', 'Josa'), ('꺾으며', 'Verb'), ('적수', 'Noun'), ('가', 'Josa'), ('없', 'Adjective'), ('음', 'Noun'), ('을', 'Josa'), ('증명', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('대국', 'Noun'), ('에', 'Josa'), ('앞서', 'Noun'), ('김', 'Noun'), ('지석', 'Noun'), ('9', 'Number'), ('단', 'Noun'), ('은', 'Josa'), ('“', 'Foreign'), ('한', 'Verb'), ('돌', 'Noun'), ('의', 'Josa'), ('바둑', 'Noun'), ('을', 'Josa'), ('유심', 'Noun'), ('히', 'Adverb'), ('많이', 'Adverb'), ('봤다', 'Verb'), ('”', 'Foreign'), ('며', 'Noun'), ('“', 'Foreign'), ('실력', 'Noun'), ('은', 'Josa'), ('사람과', 'Noun'), ('비교', 'Noun'), ('하기', 'Verb'), ('힘들', 'Adjective'), ('정도', 'Noun'), ('로', 'Josa'), ('강하', 'Noun'), ('지만', 'Josa'), ('승부', 'Noun'), ('는', 'Josa'), ('모르는', 'Verb'), ('것', 'Noun'), ('이기', 'Noun'), ('때문', 'Noun'), ('에', 'Josa'), ('마지막', 'Noun'), ('까지', 'Josa'), ('이', 'Determiner'), ('기기', 'Noun'), ('위해', 'Noun'), ('최선', 'Noun'), ('을', 'Josa'), ('다', 'Adverb'), ('할', 'Verb'), ('것', 'Noun'), ('”', 'Foreign'), ('이라고', 'Josa'), ('각오', 'Noun'), ('를', 'Josa'), ('밝혔다', 'Verb'), ('.', 'Punctuation'), ('두', 'Noun'), ('번의', 'Noun'), ('대국', 'Noun'), ('에서', 'Josa'), ('완승', 'Noun'), ('을', 'Josa'), ('거둔', 'Verb'), ('한', 'Verb'), ('돌은', 'Verb'), ('김', 'Noun'), ('지석', 'Noun'), ('9', 'Number'), ('단', 'Noun'), ('과의', 'Josa'), ('경기', 'Noun'), ('에서도', 'Josa'), ('탄탄한', 'Adjective'), ('행마', 'Noun'), ('로', 'Josa'), ('국면', 'Noun'), ('을', 'Josa'), ('설계', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('한', 'Verb'), ('돌은', 'Verb'), ('우', 'Adverb'), ('중앙', 'Noun'), ('붙임수', 'Verb'), ('이후', 'Noun'), ('중앙', 'Noun'), ('일대', 'Noun'), ('에', 'Josa'), ('집', 'Noun'), ('을', 'Josa'), ('장만', 'Noun'), ('하면서', 'Verb'), ('승기', 'Noun'), ('를', 'Josa'), ('잡았다', 'Verb'), ('.', 'Punctuation'), ('이번', 'Noun'), ('대결', 'Noun'), ('들어', 'Verb'), ('처음', 'Noun'), ('으로', 'Josa'), ('끝내기', 'Noun'), ('를', 'Josa'), ('보여주며', 'Verb'), ('계', 'Noun'), ('가까지', 'Verb'), ('간', 'Noun'), ('바둑', 'Noun'), ('은', 'Josa'), ('한', 'Verb'), ('돌', 'Noun'), ('의', 'Josa'), ('느슨함과', 'Adjective'), ('김', 'Noun'), ('지석', 'Noun'), ('9', 'Number'), ('단', 'Noun'), ('의', 'Josa'), ('추격', 'Noun'), ('으로', 'Josa'), ('차이', 'Noun'), ('가', 'Josa'), ('좁혀', 'Verb'), ('졌으나', 'Verb'), ('덤', 'Noun'), ('이', 'Josa'), ('나오지', 'Verb'), ('않았다', 'Verb'), ('.', 'Punctuation'), ('국', 'Noun'), ('후', 'Noun'), ('김', 'Noun'), ('지석', 'Noun'), ('9', 'Number'), ('단', 'Noun'), ('은', 'Josa'), ('“', 'Foreign'), ('결과', 'Noun'), ('는', 'Josa'), ('큰', 'Verb'), ('차이', 'Noun'), ('가', 'Josa'), ('아니었지만', 'Adjective'), ('마지막', 'Noun'), ('에', 'Josa'), ('한', 'Verb'), ('돌이', 'Noun'), ('봐', 'Verb'), ('준', 'Noun'), ('것', 'Noun'), ('같은', 'Adjective'), ('느낌', 'Noun'), ('”', 'Foreign'), ('이', 'Determiner'), ( ...

# %%
# 불용어(어미, 구두점, 조사 , 외국어, 알파벳, 숫자등과 최빈어)제거
word = []
stopPos = ['Suffix','Punctuation','Josa','Foreign','Alpha','Number','ScreenName']
stopWord = ['사진','엔터테인먼트','음','때문','한편','무단','칼','럼','했다','라며','있다',
            '이어','졌으나','덧붙였다','않았다','고수','재테크','배포','이','재','및','금지']
for tag in oktTag:
    if tag[1] not in stopPos:
        if tag[0] not in stopWord:
            word.append(tag[0])

print(word)
# Out:
# ['바둑', '인공', '지능', '한', '돌', '프로', '기사', '상대로', '연승', '거두며', '무서운', '기세', '올렸다', '따르면', '한', '돌은', '전날', '밤', '펼쳐진', '김', '지석', '단', '대국', '시간', '분만', '수로', '백', '불계승', '거뒀다', '한', '돌은', '신민', '준', '이동', '훈', '단', '국내', '바둑', '랭킹', '위인', '김', '지석', '단', '꺾으며', '적수', '없', '증명', '대국', '앞서', '김', '지석', '단', '한', '돌', '바둑', '유심', '히', '많이', '봤다', '며', '실력', '사람과', '비교', '하기', '힘들', '정도', '강하', '승부', '모르는', '것', '이기', '마지막', '기기', '위해', '최선', '다', '할', '것', '각오', '밝혔다', '두', '번의', '대국', '완승', '거둔', '한', '돌은', '김', '지석', '단', '경기', '탄탄한', '행마', '국면', '설계', '한', '돌은', '우', '중앙', '붙임수', '이후', '중앙', '일대', '집', '장만', '하면서', '승기', '잡았다', '이번', '대결', '들어', '처음', '끝내기', '보여주며', '계', '가까지', '간', '바둑', '한', '돌', '느슨함과', '김', '지석', '단', '추격', '차이', '좁혀', '덤', '나오지', '국', '후', '김', '지석', '단', '결과', '큰', '차이', '아니었지만', '마지막', '한', '돌이', '봐', '준', '것', '같은', '느낌', '예상', '수', '두', '갑갑했고', '어디서', '크게', '실수', '했는지', '잘', '모르겠지만', '많이', '나빴던', '것', '같다', '고', '말', '그', '사람과', '대국', '다', '면', '나중', '기회', '올', '거', '생각', '가졌을', '텐데', '와', '두다', '보니', '심리', '위축', '된', '점도', '있었다', '고', '한', '돌은', '오는', '밤', '국내', '바둑', '랭킹', '위', '박정', '환', '단', '제', '국', '갖는다', '해설', '강남', '바둑', '센터', '도', '은', '교', '프로', '맡을', '예정', '시청자', '유', '튜브', '실시간', '감상', '할', '수', '채', '성오', '기자', '저작권', '성공', '꿈꾸는', '사람', '경제', '뉴스', '머니', '전', '비법', '박학', '다식', '이건', '희']

# %%
#최빈어 검색(불용어 제거를 위함)
from collections import Counter 
Counter(word).most_common()
# Out:
# [('한', 9),
#  ('단', 8),
#  ('바둑', 6),
#  ('김', 6),
#  ('지석', 6),
#  ('돌은', 5),
#  ('대국', 4),
#  ('것', 4),
#  ('돌', 3),
#  ('프로', 2),
#  ('밤', 2),
#  ('준', 2),
#  ('이어', 2),
#  ('국내', 2),
#  ('랭킹', 2),
#  ('많이', 2),
#  ('사람과', 2),
#  ('마지막', 2),
#  ('다', 2),
#  ('할', 2),
#  ('두', 2),
#  ('중앙', 2),
#  ('차이', 2),
#  ('국', 2),
#  ('수', 2),
#  ('고', 2),
#  ('인공', 1),
#  ('지능', 1),
#  ('기사', 1),
#  ('상대로', 1),
#  ('연승', 1),
#  ('거두며', 1),
#  ('무서운', 1),
#  ('기세', 1),
#  ('올렸다', 1),
#  ('따르면', 1),
#  ('전날', 1),
#  ('펼쳐진', 1),
#  ('시간', 1),
#  ('분만', 1),
#  ('수로', 1),
#  ('백', 1),
#  ('불계승', 1),
#  ('거뒀다', 1),
#  ('신민', 1),
#  ('이동', 1),
#  ('훈', 1),
#  ('위인', 1),
#  ('꺾으며', 1),
#  ('적수', 1),
#  ('없', 1),
#  ('증명', 1),
#  ('앞서', 1),
#  ('유심', 1),
#  ('히', 1),
#  ('봤다', 1),
#  ('며', 1),
#  ('실력', 1),
#  ('비교', 1),
#  ('하기', 1),
#  ('힘들', 1),
#  ('정도', 1),
#  ('강하', 1),
#  ('승부', 1),
#  ('모르는', 1),
#  ('이기', 1),
#  ('기기', 1),
#  ('위해', 1),
#  ('최선', 1),
#  ('각오', 1),
#  ('밝혔다', 1),
#  ('번의', 1),
#  ('완승', 1),
#  ('거둔', 1),
#  ('경기', 1),
#  ('탄탄한', 1),
#  ('행마', 1),
#  ('국면', 1),
#  ('설계', 1),
#  ('우', 1),
#  ('붙임수', 1),
#  ('이후', 1),
#  ('일대', 1),
#  ('집', 1),
#  ('장만', 1),
#  ('하면서', 1),
#  ('승기', 1),
#  ('잡았다', 1),
#  ('이번', 1),
#  ('대결', 1),
#  ('들어', 1),
#  ('처음', 1),
#  ('끝내기', 1),
#  ('보여주며', 1),
#  ('계', 1),
#  ('가까지', 1),
#  ('간', 1),
#  ('느슨함과', 1),
#  ('추격', 1),
#  ('좁혀', 1),
#  ('덤', 1),
#  ('나오지', 1),
#  ('후', 1),
#  ('결과', 1),
#  ('큰', 1),
#  ('아니었지만', 1),
#  ('돌이', 1),
#  ('봐', 1),
#  ('같은', 1),
#  ('느낌', 1),
#  ('라며', 1),
#  ('예상', 1),
#  ('갑갑했고', 1),
#  ('어디서', 1),
#  ('크게', 1),
#  ('실수', 1),
#  ('했는지', 1),
#  ('잘', 1),
#  ('모르겠지만', 1),
#  ('나빴던', 1),
#  ('같다', 1),
#  ('말', 1),
#  ('그', 1),
#  ('면', 1),
#  ('나중', 1),
#  ('기회', 1),
#  ('올', 1),
#  ('거', 1),
#  ('생각', 1),
#  ('가졌을', 1),
#  ('텐데', 1),
#  ('와', 1),
#  ('두다', 1),
#  ('보니', 1),
#  ('심리', 1),
#  ('위축', 1),
#  ('된', 1),
#  ('점도', 1),
#  ('있었다', 1),
#  ('오는', 1),
#  ('위', 1),
#  ('박정', 1),
#  ('환', 1),
#  ('제', 1),
#  ('갖는다', 1),
#  ('해설', 1),
#  ('강남', 1),
#  ('센터', 1),
#  ('도', 1),
#  ('은', 1),
#  ('교', 1),
#  ('맡을', 1),
#  ('예정', 1),
#  ('시청자', 1),
#  ('유', 1),
#  ('튜브', 1),
#  ('실시간', 1),
#  ('감상', 1),
#  ('있다', 1),
#  ('채', 1),
#  ('성오', 1),
#  ('기자', 1),
#  ('저작권', 1),
#  ('성공', 1),
#  ('꿈꾸는', 1),
#  ('사람', 1),
#  ('경제', 1),
#  ('뉴스', 1),
#  ('머니', 1),
#  ('전', 1),
#  ('비법', 1),
#  ('박학', 1),
#  ('다식', 1),
#  ('이건', 1),
#  ('희', 1)]
