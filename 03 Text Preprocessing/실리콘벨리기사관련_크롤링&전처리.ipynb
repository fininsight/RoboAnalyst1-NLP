# %%
import requests
from bs4 import BeautifulSoup
from konlpy.tag import Kkma
from konlpy.tag import Okt

# %%
#크롤링
url = 'http://news.chosun.com/site/data/html_dir/2018/07/10/2018071004121.html'
response = requests.get(url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text,'html.parser')
news = soup.select('div[class="par"]')

# %%
# 토큰화
for newsText in news:
    token = Kkma().sentences(newsText.text)

# %%
# 형태소분석
oktTag = []

for sentence in token:
    oktTag += Okt().pos(sentence)

print(oktTag)
# Out:
# [('교육', 'Noun'), ('을', 'Josa'), ('삶', 'Noun'), ('의', 'Josa'), ('최', 'Noun'), ('우선', 'Noun'), ('순위', 'Noun'), ('로', 'Josa'), ('두고', 'Verb'), ('있는', 'Adjective'), ('한국', 'Noun'), ('의', 'Josa'), ('부모', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('대학', 'Noun'), ('전공', 'Noun'), ('가운데', 'Noun'), ('의학과', 'Noun'), ('공학', 'Noun'), ('·', 'Punctuation'), ('과학', 'Noun'), ('을', 'Josa'), ('중시', 'Noun'), ('한다', 'Verb'), ('.', 'Punctuation'), ('자녀', 'Noun'), ('의', 'Josa'), ('직업', 'Noun'), ('적', 'Suffix'), ('성공', 'Noun'), ('을', 'Josa'), ('위해', 'Noun'), ('대학', 'Noun'), ('전공', 'Noun'), ('으로', 'Josa'), ('의학과', 'Noun'), ('이공', 'Noun'), ('계', 'Suffix'), ('를', 'Josa'), ('우선', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('고려', 'Noun'), ('하는', 'Verb'), ('일', 'Noun'), ('은', 'Josa'), ('한국', 'Noun'), ('이', 'Josa'), ('산업화', 'Noun'), ('중이', 'Noun'), ('던', 'Noun'), ('상황', 'Noun'), ('에선', 'Josa'), ('올바른', 'Adjective'), ('선택', 'Noun'), ('이었다', 'Verb'), ('.', 'Punctuation'), ('하지만', 'Conjunction'), ('지금', 'Noun'), ('은', 'Josa'), ('모든', 'Noun'), ('것', 'Noun'), ('이', 'Josa'), ('달라졌다', 'Verb'), ('.', 'Punctuation'), ('요즘', 'Noun'), ('실리콘밸리', 'Noun'), ('에서', 'Josa'), ('확인', 'Noun'), ('되는', 'Verb'), ('것', 'Noun'), ('은', 'Josa'), ('4', 'Number'), ('차', 'Noun'), ('산업혁명', 'Noun'), ('시대', 'Noun'), ('에는', 'Josa'), ('예술', 'Noun'), ('과', 'Josa'), ('인문학', 'Noun'), ('이', 'Josa'), ('의학', 'Noun'), ('·', 'Punctuation'), ('공학', 'Noun'), ('만큼', 'Josa'), ('중요', 'Noun'), ('하다는', 'Verb'), ('사실', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation'), ('스티브', 'Noun'), ('잡스', 'Noun'), ('는', 'Josa'), ('자신', 'Noun'), ('이', 'Josa'), ('대학', 'Noun'), ('시절', 'Noun'), ('수강', 'Noun'), ('했던', 'Verb'), ('서체', 'Noun'), ('(', 'Punctuation'), ('書體', 'Foreign'), (')', 'Punctuation'), ('수업', 'Noun'), ('이', 'Josa'), ('매킨토시', 'Noun'), ('(', 'Punctuation'), ('애플', 'Noun'), ('이', 'Josa'), ('1984년', 'Number'), ('발표', 'Noun'), ('한', 'Josa'), ('개인', 'Noun'), ('용', 'Noun'), ('컴퓨터', 'Noun'), (')', 'Punctuation'), ('개발', 'Noun'), ('성공', 'Noun'), ('에', 'Josa'), ('큰', 'Verb'), ('영향', 'Noun'), ('을', 'Josa'), ('미쳤다고', 'Adjective'), ('말', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('그', 'Noun'), ('는', 'Josa'), ('2011년', 'Number'), ('아이', 'Noun'), ('패드', 'Noun'), ('2', 'Number'), ('를', 'Noun'), ('공개', 'Noun'), ('하면서', 'Verb'), ('"', 'Punctuation'), ('애플', 'Noun'), ('의', 'Josa'), ('DNA', 'Alpha'), ('는', 'Verb'), ('기술', 'Noun'), ('만으로는', 'Josa'), ('충분하지', 'Adjective'), ('않다', 'Verb'), ('.', 'Punctuation'), ('교양', 'Noun'), ('과', 'Josa'), ('인문학', 'Noun'), ('이', 'Josa'), ('결합', 'Noun'), ('한', 'Josa'), ('기술', 'Noun'), ('이야말로', 'Josa'), ('가슴', 'Noun'), ('벅찬', 'Adjective'), ('결과', 'Noun'), ('를', 'Josa'), ('낳을', 'Noun'), ('것', 'Noun'), ('"', 'Punctuation'), ('이', 'Determiner'), ('라며', 'Noun'), ('예술', 'Noun'), ('과', 'Josa'), ('디자인', 'Noun'), ('의', 'Josa'), ('중요성', 'Noun'), ('을', 'Josa'), ('강조', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('이런', 'Adjective'), ('관점', 'Noun'), ('을', 'Josa'), ('바탕', 'Noun'), ('으로', 'Josa'), ('잡스', 'Noun'), ('는', 'Josa'), ('세계', 'Noun'), ('최고', 'Noun'), ('가치', 'Noun'), ('를', 'Josa'), ('인정받는', 'Verb'), ('기업', 'Noun'), ('을', 'Josa'), ('만들었고', 'Verb'), (',', 'Punctuation'), ('기술', 'Noun'), ('산업', 'Noun'), ('의', 'Josa'), ('새로운', 'Adjective'), ('표준', 'Noun'), ('까지', 'Josa'), ('정', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('실리콘', 'Noun'), ('밸리', 'Noun'), ('에서', 'Josa'), ('최근', 'Noun'), ('뜨고', 'Verb'), ('있는', 'Adjective'), ('스타', 'Noun'), ('기업인', 'Noun'), ('중', 'Noun'), ('에는', 'Josa'), ('인문학', 'Noun'), ('전공자', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('제법', 'Noun'), ('많다', 'Adjective'), ('.', 'Punctuation'), ('구인', 'Noun'), ('·', 'Punctuation'), ('구직', 'Noun'), ('소', 'Noun'), ('셜', 'Noun'), ('네트', 'Noun'), ('워킹', 'Noun'), ('서비스', 'Noun'), ('기업인', 'Noun'), ('링크', 'Noun'), ('드', 'Noun'), ('인', 'Josa'), ('(', 'Punctuation'), ('LinkedIn', 'Alpha'), (')', 'Punctuation'), ('창업', 'Noun'), ('자', 'Suffix'), ('리드', 'Noun'), ('호프', 'Noun'), ('만은', 'Josa'), ('철학', 'Noun'), ('석사', 'Noun'), ('학위', 'Noun'), ('소지', 'N ...

# %%
# 불용어(어미, 구두점, 조사 , 외국어, 알파벳, 숫자와 최빈어)제거
word = []
stopPos = ['Suffix','Punctuation','Josa','Foreign','Alpha','Number']
stopword = ['했다','것','있는','한다','하는','그','있다','할','를','이','이런',
           '되기','해야','있게','여기']

for tag in oktTag:
    if tag[1] not in stopPos:
        if tag[0] not in stopword:
            word.append(tag[0])

print(word)
# Out:
# ['교육', '삶', '최', '우선', '순위', '두고', '한국', '부모', '대학', '전공', '가운데', '의학과', '공학', '과학', '중시', '자녀', '직업', '성공', '위해', '대학', '전공', '의학과', '이공', '우선', '고려', '일', '한국', '산업화', '중이', '던', '상황', '올바른', '선택', '이었다', '하지만', '지금', '모든', '달라졌다', '요즘', '실리콘밸리', '확인', '되는', '차', '산업혁명', '시대', '예술', '인문학', '의학', '공학', '중요', '하다는', '사실', '스티브', '잡스', '자신', '대학', '시절', '수강', '했던', '서체', '수업', '매킨토시', '애플', '발표', '개인', '용', '컴퓨터', '개발', '성공', '큰', '영향', '미쳤다고', '말', '아이', '패드', '공개', '하면서', '애플', '는', '기술', '충분하지', '않다', '교양', '인문학', '결합', '기술', '가슴', '벅찬', '결과', '낳을', '라며', '예술', '디자인', '중요성', '강조', '관점', '바탕', '잡스', '세계', '최고', '가치', '인정받는', '기업', '만들었고', '기술', '산업', '새로운', '표준', '정', '실리콘', '밸리', '최근', '뜨고', '스타', '기업인', '중', '인문학', '전공자', '제법', '많다', '구인', '구직', '소', '셜', '네트', '워킹', '서비스', '기업인', '링크', '드', '창업', '리드', '호프', '철학', '석사', '학위', '소지', '수', '잔', '보이치', '키', '유', '튜브', '는', '역사', '문학', '전공', '메신저', '개발', '업체', '슬', '랙', '의', '창업', '스튜', '어트', '버터', '필드', '철학', '세계', '최대', '숙박', '공유', '기업인', '에어', '비', '앤', '비', '설립', '브라', '이언', '체', '스키', '미술', '전공', '중국', '알', '리', '바', '바', '그룹', '마', '윈', '회장', '학부', '전공', '영어', '였다', '내', '속', '해', '하버드', '대', '듀', '크대', '연구', '팀', '미국', '기업', '창업', '자', '가', '학사', '학위', '는', '석사', '학위', '이상', '갖고', '있', '음', '밝혀냈다', '창업', '자', '세부', '전공', '보면', '만', '공학', '컴퓨터', '기술', '수학', '전공자', '뿐이었다', '전공', '경영', '회계', '보건', '예술', '인문학', '등', '매우', '다양했다', '컴퓨터', '주변기기', '제조', '업체', '로지텍', '브랙', '큰', '대', '럴', '도', '영문학', '전공', '최근', '내', '어떻게', '여', '회사', '주가', '올릴', '수', '있었느냐', '고', '물었더니', '우리', '회사', '만드는', '모든', '제품', '디자인', '쉼', '없이', '고민', '했기', '때문', '가능했다', '기술', '관련', '제품', '성공', '가장', '중요한', '디자인', '답', '차', '산업혁명', '혁신', '규칙', '바꾸는', '일이', '컴퓨터', '인공', '지능', '디지털', '의술', '로봇공학', '합성', '생물학', '등', '광범위한', '기술', '활용', '된다', '의학', '인공', '지능', '센서', '융합', '하면', '인간', '건강', '진단', '질병', '예방', '디지털', '의사', '만들', '수', '유전체', '학과', '유전자', '편집', '이용', '해', '가뭄', '강하고', '인류', '전체', '먹여', '살릴', '새', '식물', '개발', '수', '인공', '지능', '로봇', '사용', '해', '노인', '위', '디지털', '친구', '도', '가능하다', '초소', '물질', '발전', '모든', '사람', '충분히', '이용', '수', '태양', '열', '저장', '기술', '의', '새', '시대', '열', '해결', '책', '이끌어내는', '데', '생물학', '교육', '의료', '인간', '행동', '등', '여러', '분야', '대한', '지식', '필요하다', '우리', '처', '거대한', '사회', '기술', '도전', '대처', '하려면', '인류', '둘러싼', '다양한', '배경', '맥락', '대해', '비판', '사고', '능력', '필수', '이는', '인문학', '전공자', '가장', '잘', '훈련', '받은', '분야', '일례', '음악', '예술', '문학', '심리학', '비롯', '공감', '능력', '디자인', '큰', '장점', '된다', '로마', '제국', '흥망', '성쇠', '계몽', '주의', '공부', '역사', '학도', '기술', '인간', '요소', '유용성', '대한', '통찰', '가질', '수', '심리학', '전공자', '사람', '동기', '부여', '무엇', '사용자', '원하는', '게', '무엇', '인지', '공학', '한', '분야', '일해', '온', '엔지니어', '잘', '이해', '수', '우리', '상상', '물건', '로', '만들', '수', '되면', '음악가', '나', '화가', '세상', '될지도', '모른다', '자녀', '미래', '어떤', '직업', '택하', '좋겠는', '가', '질문', '받을', '때', '나', '아이', '스스로', '하고', '싶은', '선택', '하도록', '내버려', '두는', '게', '최선', '답', '과거', '우리', '부모', '우리', '공부', '강요', '해서', '학습', '억지로', '따분한', '일', '로', '했던', '방식', '따라', '해선', '안', '된다', '대신', '자녀', '자신', '열정', '추구', '배우는', '걸', '즐길', '수', '있도록', '북', '돋아야', '기술', '통해', '놀라운', '미래', '창조', '새로운', '산업혁명', '시대', '리더', '위해', '한국', '공학자', '손잡고', '일', '음악가', '화가', '더', '많이', '필요하다', '이제', '과학', '공학', '의학', '아니라', '창의', '성과', '디자인', '진정한', '관심', '쏟아야']

# %%
#최빈어 검색(불용어 제거를 위함)
from collections import Counter 
Counter(word).most_common()
# Out:
# [('기술', 10),
#  ('수', 9),
#  ('전공', 8),
#  ('공학', 5),
#  ('인문학', 5),
#  ('디자인', 5),
#  ('우리', 5),
#  ('예술', 4),
#  ('컴퓨터', 4),
#  ('전공자', 4),
#  ('창업', 4),
#  ('한국', 3),
#  ('대학', 3),
#  ('자녀', 3),
#  ('성공', 3),
#  ('일', 3),
#  ('모든', 3),
#  ('산업혁명', 3),
#  ('시대', 3),
#  ('의학', 3),
#  ('개발', 3),
#  ('큰', 3),
#  ('는', 3),
#  ('기업인', 3),
#  ('학위', 3),
#  ('해', 3),
#  ('등', 3),
#  ('인공', 3),
#  ('지능', 3),
#  ('디지털', 3),
#  ('된다', 3),
#  ('인간', 3),
#  ('분야', 3),
#  ('교육', 2),
#  ('우선', 2),
#  ('부모', 2),
#  ('의학과', 2),
#  ('과학', 2),
#  ('직업', 2),
#  ('위해', 2),
#  ('선택', 2),
#  ('차', 2),
#  ('잡스', 2),
#  ('자신', 2),
#  ('했던', 2),
#  ('애플', 2),
#  ('아이', 2),
#  ('세계', 2),
#  ('기업', 2),
#  ('새로운', 2),
#  ('최근', 2),
#  ('철학', 2),
#  ('석사', 2),
#  ('역사', 2),
#  ('문학', 2),
#  ('업체', 2),
#  ('의', 2),
#  ('비', 2),
#  ('바', 2),
#  ('내', 2),
#  ('대', 2),
#  ('자', 2),
#  ('가', 2),
#  ('도', 2),
#  ('회사', 2),
#  ('제품', 2),
#  ('가장', 2),
#  ('답', 2),
#  ('여기', 2),
#  ('생물학', 2),
#  ('만들', 2),
#  ('이용', 2),
#  ('인류', 2),
#  ('새', 2),
#  ('사람', 2),
#  ('열', 2),
#  ('대한', 2),
#  ('필요하다', 2),
#  ('능력', 2),
#  ('잘', 2),
#  ('심리학', 2),
#  ('공부', 2),
#  ('무엇', 2),
#  ('게', 2),
#  ('로', 2),
#  ('음악가', 2),
#  ('나', 2),
#  ('화가', 2),
#  ('미래', 2),
#  ('삶', 1),
#  ('최', 1),
#  ('순위', 1),
#  ('두고', 1),
#  ('가운데', 1),
#  ('중시', 1),
#  ('이공', 1),
#  ('고려', 1),
#  ('산업화', 1),
#  ('중이', 1),
#  ('던', 1),
#  ('상황', 1),
#  ('올바른', 1),
#  ('이었다', 1),
#  ('하지만', 1),
#  ('지금', 1),
#  ('달라졌다', 1),
#  ('요즘', 1),
#  ('실리콘밸리', 1),
#  ('확인', 1),
#  ('되는', 1),
#  ('중요', 1),
#  ('하다는', 1),
#  ('사실', 1),
#  ('스티브', 1),
#  ('시절', 1),
#  ('수강', 1),
#  ('서체', 1),
#  ('수업', 1),
#  ('매킨토시', 1),
#  ('발표', 1),
#  ('개인', 1),
#  ('용', 1),
#  ('영향', 1),
#  ('미쳤다고', 1),
#  ('말', 1),
#  ('패드', 1),
#  ('공개', 1),
#  ('하면서', 1),
#  ('충분하지', 1),
#  ('않다', 1),
#  ('교양', 1),
#  ('결합', 1),
#  ('가슴', 1),
#  ('벅찬', 1),
#  ('결과', 1),
#  ('낳을', 1),
#  ('라며', 1),
#  ('중요성', 1),
#  ('강조', 1),
#  ('관점', 1),
#  ('바탕', 1),
#  ('최고', 1),
#  ('가치', 1),
#  ('인정받는', 1),
#  ('만들었고', 1),
#  ('산업', 1),
#  ('표준', 1),
#  ('정', 1),
#  ('실리콘', 1),
#  ('밸리', 1),
#  ('뜨고', 1),
#  ('스타', 1),
#  ('중', 1),
#  ('제법', 1),
#  ('많다', 1),
#  ('구인', 1),
#  ('구직', 1),
#  ('소', 1),
#  ('셜', 1),
#  ('네트', 1),
#  ('워킹', 1),
#  ('서비스', 1),
#  ('링크', 1),
#  ('드', 1),
#  ('리드', 1),
#  ('호프', 1),
#  ('소지', 1),
#  ('잔', 1),
#  ('보이치', 1),
#  ('키', 1),
#  ('유', 1),
#  ('튜브', 1),
#  ('메신저', 1),
#  ('슬', 1),
#  ('랙', 1),
#  ('스튜', 1),
#  ('어트', 1),
#  ('버터', 1),
#  ('필드', 1),
#  ('최대', 1),
#  ('숙박', 1),
#  ('공유', 1),
#  ('에어', 1),
#  ('앤', 1),
#  ('설립', 1),
#  ('브라', 1),
#  ('이언', 1),
#  ('체', 1),
#  ('스키', 1),
#  ('미술', 1),
#  ('중국', 1),
#  ('알', 1),
#  ('리', 1),
#  ('그룹', 1),
#  ('마', 1),
#  ('윈', 1),
#  ('회장', 1),
#  ('학부', 1),
#  ('영어', 1),
#  ('였다', 1),
#  ('속', 1),
#  ('하버드', 1),
#  ('듀', 1),
#  ('크대', 1),
#  ('연구', 1),
#  ('팀', 1),
#  ('미국', 1),
#  ('학사', 1),
#  ('이상', 1),
#  ('갖고', 1),
#  ('있', 1),
#  ('음', 1),
#  ('밝혀냈다', 1),
#  ('세부', 1),
#  ('보면', 1),
#  ('만', 1),
#  ('수학', 1),
#  ('뿐이었다', 1),
#  ('경영', 1),
#  ('회계', 1),
#  ('보건', 1),
#  ('매우', 1),
#  ('다양했다', 1),
#  ('주변기기', 1),
#  ('제조', 1),
#  ('로지텍', 1),
#  ('브랙', 1),
#  ('럴', 1),
#  ('영문학', 1),
#  ('어떻게', 1),
#  ('여', 1),
#  ('주가', 1),
#  ('올릴', 1),
#  ('있었느냐', 1),
#  ('고', 1),
#  ('물었더니', 1),
#  ('만드는', 1),
#  ('쉼', 1),
#  ('없이', 1),
#  ('고민', 1),
#  ('했기', 1),
#  ('때문', 1),
#  ('가능했다', 1),
#  ('관련', 1),
#  ('중요한', 1),
#  ('혁신', 1),
#  ('규칙', 1),
#  ('바꾸는', 1),
#  ('일이', 1),
#  ('의술', 1),
#  ('로봇공학', 1),
#  ('합성', 1),
#  ('광범위한', 1),
#  ('활용', 1),
#  ('센서', 1),
#  ('융합', 1),
#  ('하면', 1),
#  ('건강', 1),
#  ('진단', 1),
#  ('질병', 1),
#  ('예방', 1),
#  ('의사', 1),
#  ('유전체', 1),
#  ('학과', 1),
#  ('유전자', 1),
#  ('편집', 1),
#  ('가뭄', 1),
#  ('강하고', 1),
#  ('전체', 1),
#  ('먹여', 1),
#  ('살릴', 1),
#  ('식물', 1),
#  ('로봇', 1),
#  ('사용', 1),
#  ('노인', 1),
#  ('위', 1),
#  ('친구', 1),
#  ('가능하다', 1),
#  ('초소', 1),
#  ('물질', 1),
#  ('발전', 1),
#  ('충분히', 1),
#  ('태양', 1),
#  ('저장', 1),
#  ('해결', 1),
#  ('책', 1),
#  ('이끌어내는', 1),
#  ('데', 1),
#  ('의료', 1),
#  ('행동', 1),
#  ('여러', 1),
#  ('지식', 1),
#  ('처', 1),
#  ('거대한', 1),
#  ('사회', 1),
#  ('도전', 1),
#  ('대처', 1),
#  ('하려면', 1),
#  ('둘러싼', 1),
#  ('다양한', 1),
#  ('배경', 1),
#  ('맥락', 1),
#  ('대해', 1),
#  ('비판', 1),
#  ('사고', 1),
#  ('필수', 1),
#  ('이는', 1),
#  ('훈련', 1),
#  ('받은', 1),
#  ('일례', 1),
#  ('음악', 1),
#  ('비롯', 1),
#  ('공감', 1),
#  ('장점', 1),
#  ('로마', 1),
#  ('제국', 1),
#  ('흥망', 1),
#  ('성쇠', 1),
#  ('계몽', 1),
#  ('주의', 1),
#  ('학도', 1),
#  ('요소', 1),
#  ('유용성', 1),
#  ('통찰', 1),
#  ('가질', 1),
#  ('동기', 1),
#  ('부여', 1),
#  ('사용자', 1),
#  ('원하는', 1),
#  ('인지', 1),
#  ('한', 1),
#  ('일해', 1),
#  ('온', 1),
#  ('엔지니어', 1),
#  ('이해', 1),
#  ('상상', 1),
#  ('물건', 1),
#  ('있게', 1),
#  ('되면', 1),
#  ('세상', 1),
#  ('될지도', 1),
#  ('모른다', 1),
#  ('어떤', 1),
#  ('택하', 1),
#  ('좋겠는', 1),
#  ('질문', 1),
#  ('받을', 1),
#  ('때', 1),
#  ('스스로', 1),
#  ('하고', 1),
#  ('싶은', 1),
#  ('하도록', 1),
#  ('내버려', 1),
#  ('두는', 1),
#  ('최선', 1),
#  ('과거', 1),
#  ('강요', 1),
#  ('해서', 1),
#  ('학습', 1),
#  ('억지로', 1),
#  ('해야', 1),
#  ('따분한', 1),
#  ('방식', 1),
#  ('따라', 1),
#  ('해선', 1),
#  ('안', 1),
#  ('대신', 1),
#  ('열정', 1),
#  ('추구', 1),
#  ('배우는', 1),
#  ('걸', 1),
#  ('즐길', 1),
#  ('있도록', 1),
#  ('북', 1),
#  ('돋아야', 1),
#  ('통해', 1),
#  ('놀라운', 1),
#  ('창조', 1),
#  ('리더', 1),
#  ('되기', 1),
#  ('공학자', 1),
#  ('손잡고', 1),
#  ('더', 1),
#  ('많이', 1),
#  ('이제', 1),
#  ('아니라', 1),
#  ('창의', 1),
#  ('성과', 1),
#  ('진정한', 1),
#  ('관심', 1),
#  ('쏟아야', 1)]
